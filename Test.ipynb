# %%
import pandas as pd

# %%
df = pd.read_excel("UDX_Hotel_Data.xlsx")

# %%
df.head()
# Out:
#   Arrival_Date  Revenue  Room_Nights  Reservations    Adr  Bookings_Window  \
# 0   2024-01-30     74.4            1             1   74.4                0
# 1   2024-10-15     96.0            1             1   96.0                0
# 2   2025-04-17    107.0            1             1  107.0                0
# 3   2024-12-20    102.0            1             1  102.0                0
# 4   2024-03-11    132.0            1             1  132.0                0
#
#   Hotel_Name  Py_Revenue  Py_Room_Nights  Py_Reservations  ...  Location  \
# 0   Dockside         0.0               0                0  ...       UOR
# 1   Dockside         0.0               0                0  ...       UOR
# 2   Dockside         0.0               0                0  ...       UOR
# 3   Dockside         0.0               0                0  ...       UOR
# 4   Dockside         0.0               0                0  ...       UOR
#
#         Hotel_Category Promocode Origin_Level_1 Sales_Channel_Level_1  \
# ...

# %%
df.shape
# Out:
# (710794, 23)
